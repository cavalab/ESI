# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

os.chdir('/Volumes/chip-lacava/Private/ch269952/BIDMC')
os.getcwd()
# Out:
# '/Volumes/chip-lacava/Private/ch269952/BIDMC'

# %%
# Load binarized data
data = pd.read_csv('preprocessed-visits.csv')
complaint = pd.read_csv('triage.csv')
data = pd.merge(data, complaint, left_on='csn', right_on='stay_id', how='inner', suffixes=('', '_drop'))
columns_to_drop = [col for col in data.columns if col.endswith('_drop')]
data = data.drop(columns=columns_to_drop)

# %%
print(data.columns.tolist())
# Out:
# ['Unnamed: 0', 'X', 'csn', 'mrn', 'arrival_time', 'sex', 'race', 'age_group', 'ed_arrival_mode', 'year_group', 'is_admitted', 'ed_los', 'num_previous_admissions', 'num_previous_visits_without_admission', 'Triage_Temp', 'Triage_HR', 'Triage_RR', 'Triage_SpO2', 'Triage_SBP', 'Triage_DBP', 'Triage_Pain', 'Triage_acuity', 'CC', 'complaint_contains_abdominal_pain', 'complaint_contains_pelvic_pain', 'complaint_contains_chest_pain', 'complaint_contains_shortness_of_breath', 'complaint_contains_headache', 'complaint_contains_fever', 'complaint_contains_fall', 'complaint_contains_ortho', 'complaint_contains_dizziness', 'complaint_contains_weakness', 'complaint_contains_other_abdomen_complaint', 'complaint_contains_cough', 'complaint_contains_chest', 'complaint_contains_flank_pain', 'complaint_contains_neuro', 'complaint_contains_psych', 'complaint_contains_seizure', 'complaint_contains_crash', 'complaint_contains_vaginal', 'complaint_contains_cardiac', 'complaint_contains_syncope', 'complaint_contains_head_and_neck', 'complaint_contains_hypertension', 'complaint_contains_skin', 'complaint_contains_genitourinary', 'complaint_contains_assault', 'complaint_contains_pregnancy', 'complaint_contains_shingles', 'complaint_contains_transfer', 'complaint_contains_substance_use', 'complaint_contains_influenza', 'complaint_contains_abnormal_test', 'complaint_contains_suspected_appendicitis', 'complaint_contains_hypotension', 'complaint_contains_brain_bleed', 'complaint_contains_unresponsive', 'Triage_BP', 'diagnosis_severity', 'medrecon_diuretics', 'medrecon_all_other_therapeutic_products', 'medrecon_urologicals', 'medrecon_other_nervous_system_drugs', 'medrecon_psychoanaleptics', 'medrecon_antiepileptics', 'medrecon_calcium_channel_blockers', 'medrecon_drugs_for_constipation', 'medrecon_immunosuppressants', 'medrecon_other_dermatological_preparations', 'medrecon_vasoprotectives', 'medrecon_analgesics', 'medrecon_antidiarrheals_intestinal_antiinflammatory_antiinfective_agents', 'medrecon_antifungals_for_dermatological_use', 'medrecon_cough_and_cold_preparations', 'medrecon_gynecological_antiinfectives_and_antiseptics', 'medrecon_antihistamines_for_systemic_use', 'medrecon_antipruritics_incl_antihistamines_anesthetics_etc', 'medrecon_immunostimulants', 'medrecon_muscle_relaxants', 'medrecon_drugs_for_obstructive_airway_diseases', 'medrecon_bile_and_liver_therapy', 'medrecon_antithrombotic_agents', 'medrecon_endocrine_therapy', 'medrecon_sex_hormones_and_modulators_of_the_genital_system', 'medrecon_antivirals_for_systemic_use', 'medrecon_corticosteroids_for_systemic_use', 'medrecon_corticosteroids_dermatological_preparations', 'medrecon_nasal_preparations', 'medrecon_ophthalmological_and_otological_preparations', 'medrecon_ophthalmologicals', 'medrecon_otologicals', 'medrecon_psycholeptics', 'medrecon_antihypertensives', 'medrecon_cardiac_therapy', 'medrecon_drugs_for_acid_related_disorders', 'medrecon_drugs_for_functional_gastrointestinal_disorders', 'medrecon_antibacterials_for_systemic_use', 'medrecon_antibiotics_and_chemotherapeutics_for_dermatological_use', 'medrecon_antiprotozoals', 'medrecon_stomatological_preparations', 'medrecon_mineral_supplements', 'medrecon_lipid_modifying_agents', 'medrecon_anti_acne_preparations', 'medrecon_antineoplastic_agents', 'medrecon_agents_acting_on_the_renin_angiotensin_system', 'medrecon_beta_blocking_agents', 'medrecon_drugs_for_treatment_of_bone_diseases', 'medrecon_antianemic_preparations', 'medrecon_antiobesity_preparations_excl_diet_products', 'medrecon_anti_parkinson_drugs', 'medrecon_antiinflammatory_and_antirheumatic_products', 'medrecon_other_alimentary_tract_and_metabolism_products', 'medrecon_blood_substitutes_and_perfusion_solutions', 'medrecon_thyroid_therapy', 'medrecon_anesthetics', 'medrecon_throat_preparations', 'medrecon_antimycotics_for_systemic_use', 'medrecon_drugs_used_in_diabetes', 'medrecon_topical_products_for_joint_and_muscular_pain', 'medrecon_pituitary_and_hypothalamic_hormones_an ...

# %%
# Create empty data frame
data_bin = pd.DataFrame(index=data.index)

# CSN VALUES
data_bin['csn'] = data['csn']

# %%
# RACE
print(f"Existant Gender Values: {data['race'].unique()}")

# Add binary columns (reference gorup: White)
data_bin['is_asian'] = (data['race'] == 'Asian').astype(int)
data_bin['is_hispanic'] = (data['race'] == 'Hispanic').astype(int)
data_bin['is_black'] = (data['race'] == 'Black').astype(int)
data_bin['is_other'] = (data['race'] == 'Other').astype(int)
data_bin['is_unknown'] = (data['race'] == 'Unknown').astype(int)
# Out:
# Existant Gender Values: ['White' 'Asian' 'Other' 'Black' 'Unknown' 'Hispanic']

# %%
# SEX
print(f"Existant Gender Values: {data['sex'].unique()}")

# Add binary column (reference group: female)
data_bin['is_male'] = (data['sex'] == 'M').astype(int)
# Out:
# Existant Gender Values: ['F' 'M']

# %%
# AGE # Add binary columns (reference group: < 30)
data_bin['age_group_30_39'] = (data['age_group'] == '30-39').astype(int)
data_bin['age_group_40_49'] = (data['age_group'] == '40-49').astype(int)
data_bin['age_group_50_59'] = (data['age_group'] == '50-59').astype(int)
data_bin['age_group_60_69'] = (data['age_group'] == '60-69').astype(int)
data_bin['age_group_70_79'] = (data['age_group'] == '70-79').astype(int)
data_bin['age_group_80'] = (data['age_group'] == '80+').astype(int)

# %%
# MEANS OF ARRIVAL
print(f"Means of arrival values: {data['ed_arrival_mode'].unique()}")

# Add binary columns (reference gorup: Self)
data_bin['arrival_EMS'] = (data['ed_arrival_mode'] == 'EMS').astype(int)
data_bin['arrival_other_unknown'] = (data['ed_arrival_mode'] == 'Other/Unknown').astype(int)
# Out:
# Means of arrival values: ['EMS' 'Walk-in' 'Other/Unknown']

# %%
# PRIOR VISITS
data_bin['num_previous_admissions'] = data['num_previous_admissions']
data_bin['num_previous_visits_without_admission'] = data['num_previous_visits_without_admission']

# %%
# COMORBIDITY SCORE
data_bin['comorbidity_score'] = data['diagnosis_severity']

# %%
# TRIAGE VITALS (reference group: normal)

# HR: 
print(f"HR values: {data['Triage_HR'].unique()}")
data_bin['triage_HR_high'] = (data['Triage_HR'] == 'high').astype(int)
data_bin['triage_HR_low'] = (data['Triage_HR'] == 'low').astype(int)
data_bin['triage_HR_very_high'] = (data['Triage_HR'] == 'very_high').astype(int)
data_bin['triage_HR_unknown'] = (data['Triage_HR'] == 'nan').astype(int)

# RR:
print(f"RR values: {data['Triage_RR'].unique()}")
data_bin['triage_RR_high'] = (data['Triage_RR'] == 'high').astype(int)
data_bin['triage_RR_low'] = (data['Triage_RR'] == 'low').astype(int)
data_bin['triage_RR_unknown'] = (data['Triage_RR'] == 'nan').astype(int)

# O2 saturation:
print(f"SpO2 values: {data['Triage_SpO2'].unique()}")
data_bin['triage_SpO2_very_low'] = (data['Triage_SpO2'] == 'very_low').astype(int)
data_bin['triage_SpO2_low'] = (data['Triage_SpO2'] == 'low').astype(int)
data_bin['triage_SpO2_unknown'] = (data['Triage_SpO2'] == 'nan').astype(int)

# BP:
print(f"BP values: {data['Triage_BP'].unique()}")
data_bin['triage_bp_stage_2'] = (data['Triage_BP'] == 'Stage 2 Hypertension').astype(int)
data_bin['triage_bp_stage_1'] = (data['Triage_BP'] == 'Stage 1 Hypertension').astype(int)
data_bin['triage_bp_elevated'] = (data['Triage_BP'] == 'Elevated').astype(int)
data_bin['triage_bp_hypertensive_crisis'] = (data['Triage_BP'] == 'Hypertensive Crisis').astype(int)
data_bin['triage_bp_unknown'] = (data['Triage_BP'] == 'nan').astype(int)

# Temperature
print(f"Temperature values: {data['Triage_Temp'].unique()}")
data_bin['triage_temp_fever'] = (data['Triage_Temp'] == 'fever').astype(int)
data_bin['triage_temp_unknown'] = (data['Triage_Temp'] == 'nan').astype(int)
# Out:
# HR values: ['normal' 'high' 'low' nan 'very_high']
# RR values: ['normal' 'high' nan 'low']
# SpO2 values: ['normal' 'low' 'very_low' nan]
# BP values: ['Normal' 'Stage 1 Hypertension' 'Elevated' 'Stage 2 Hypertension'
#  'Hypertensive Crisis' nan]
# Temperature values: ['normal' 'fever' nan]

# %%
# Add binarized chief complaints
chief_complaints = ['complaint_contains_abdominal_pain', 'complaint_contains_pelvic_pain', 
                    'complaint_contains_chest_pain', 'complaint_contains_shortness_of_breath', 
                    'complaint_contains_headache', 'complaint_contains_fever', 'complaint_contains_fall', 
                    'complaint_contains_ortho', 'complaint_contains_dizziness', 
                    'complaint_contains_weakness', 'complaint_contains_other_abdomen_complaint', 
                    'complaint_contains_cough', 'complaint_contains_chest', 'complaint_contains_flank_pain', 
                    'complaint_contains_neuro', 'complaint_contains_psych', 'complaint_contains_seizure', 
                    'complaint_contains_crash', 'complaint_contains_vaginal', 'complaint_contains_cardiac', 
                    'complaint_contains_syncope', 'complaint_contains_head_and_neck', 
                    'complaint_contains_hypertension', 'complaint_contains_skin', 
                    'complaint_contains_genitourinary', 'complaint_contains_assault', 
                    'complaint_contains_pregnancy', 'complaint_contains_shingles', 
                    'complaint_contains_transfer', 'complaint_contains_substance_use', 
                    'complaint_contains_influenza', 'complaint_contains_abnormal_test', 
                    'complaint_contains_suspected_appendicitis', 'complaint_contains_hypotension', 
                    'complaint_contains_brain_bleed', 'complaint_contains_unresponsive'
]
data_bin[chief_complaints] = data[chief_complaints]

# %%
# Add other informatino: triage acuity, triage vital signs, raw chief complaints, admission flags
columns_to_add = ['temperature', 'sbp', 'dbp', 'pain', 'acuity', 'chiefcomplaint', 'is_admitted']
data_bin[columns_to_add] = data[columns_to_add]
data_bin['triage_hr'] = data['heartrate']
data_bin['triage_rr'] = data['resprate']
data_bin['triage_spo2'] = data['o2sat']

# %%
print(data_bin.columns.tolist())
# Out:
# ['csn', 'is_asian', 'is_hispanic', 'is_black', 'is_other', 'is_unknown', 'is_male', 'age_group_30_39', 'age_group_40_49', 'age_group_50_59', 'age_group_60_69', 'age_group_70_79', 'age_group_80', 'arrival_EMS', 'arrival_other_unknown', 'num_previous_admissions', 'num_previous_visits_without_admission', 'comorbidity_score', 'triage_HR_high', 'triage_HR_low', 'triage_HR_very_high', 'triage_HR_unknown', 'triage_RR_high', 'triage_RR_low', 'triage_RR_unknown', 'triage_SpO2_very_low', 'triage_SpO2_low', 'triage_SpO2_unknown', 'triage_bp_stage_2', 'triage_bp_stage_1', 'triage_bp_elevated', 'triage_bp_hypertensive_crisis', 'triage_bp_unknown', 'triage_temp_fever', 'triage_temp_unknown', 'complaint_contains_abdominal_pain', 'complaint_contains_pelvic_pain', 'complaint_contains_chest_pain', 'complaint_contains_shortness_of_breath', 'complaint_contains_headache', 'complaint_contains_fever', 'complaint_contains_fall', 'complaint_contains_ortho', 'complaint_contains_dizziness', 'complaint_contains_weakness', 'complaint_contains_other_abdomen_complaint', 'complaint_contains_cough', 'complaint_contains_chest', 'complaint_contains_flank_pain', 'complaint_contains_neuro', 'complaint_contains_psych', 'complaint_contains_seizure', 'complaint_contains_crash', 'complaint_contains_vaginal', 'complaint_contains_cardiac', 'complaint_contains_syncope', 'complaint_contains_head_and_neck', 'complaint_contains_hypertension', 'complaint_contains_skin', 'complaint_contains_genitourinary', 'complaint_contains_assault', 'complaint_contains_pregnancy', 'complaint_contains_shingles', 'complaint_contains_transfer', 'complaint_contains_substance_use', 'complaint_contains_influenza', 'complaint_contains_abnormal_test', 'complaint_contains_suspected_appendicitis', 'complaint_contains_hypotension', 'complaint_contains_brain_bleed', 'complaint_contains_unresponsive', 'temperature', 'sbp', 'dbp', 'pain', 'acuity', 'chiefcomplaint', 'is_admitted', 'triage_hr', 'triage_rr', 'triage_spo2']

# %%
data_bin.to_csv('preprocessed_BIDMC.csv')
